# %%
import os, json, re
game_dir = './games/'
POWERS = ['AUSTRIA', 'ENGLAND', 'FRANCE', 'GERMANY', 'ITALY', 'RUSSIA', 'TURKEY']

# %%
games = list(map(lambda x: game_dir + x, filter(lambda x: x.endswith('.json'), os.listdir(game_dir))))

for game in games:
    with open(game, 'r') as f:
        data = json.load(f)

    print(data['game_id'])
    humans = human_players(data)
    annotations = all_annotations(data)
    print('human players: ', humans)
    print('bot players: ', bot_players(data))
    print('number of phases: ', num_phases(data))
    print('number of phases with messages: ', num_phases_with_msg(data))
    all_messages = all_msgs(data)
    print('all messages: ', len(all_messages))
    print('messages from humans: ', len(msgs_from_humans(all_messages, humans)))
    print('messages to humans: ', len(msgs_to_humans(all_messages, humans)))
    print('messages from humans to humans: ', len(msgs_from_to_humans(all_messages, humans)))
    print('human lies: ', len(human_lies(all_messages, humans)))
    print('annotated messages: ', len(annotated_msgs(all_messages, annotations, humans)))
    print('perceived lies: ', len(perceived_lies(all_messages, annotations, humans)))
    print('\n')
    break
# Out:
# AIGame_7
# human players:  ['AUSTRIA', 'FRANCE', 'GERMANY']
# bot players:  ['ENGLAND', 'ITALY', 'RUSSIA', 'TURKEY']
# number of phases:  31
# number of phases with messages:  19
# all messages:  31
# messages from humans:  19
# messages to humans:  19
# messages from humans to humans:  19
# human lies:  5
# annotated messages:  18
# perceived lies:  9

# %%
# Out:
# {'F1901M': [{'sender': 'RUSSIA',
#    'recipient': 'AUSTRIA',
#    'time_sent': 1699103896185108,
#    'phase': 'F1901M',
#    'message': "(also, please don't be alarmed by Galicia, I just wanted to be able to ensure Rumania)",
#    'truth': None,
#    'annotation': 'yes'}],
#  'F1902M': [{'sender': 'FRANCE',
#    'recipient': 'GERMANY',
#    'time_sent': 1699105213835042,
#    'phase': 'F1902M',
#    'message': "can you support Pic in? I'd like to keep Bur to shift down to Mar if necessary.",
#    'truth': 'Truth',
#    'annotation': 'yes'}],
#  'S1903M': [{'sender': 'RUSSIA',
#    'recipient': 'GERMANY',
#    'time_sent': 1699106930674238,
#    'phase': 'S1903M',
#    'message': "Is there anything we can work out? I'd prefer not to fight you",
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'RUSSIA',
#    'recipient': 'GERMANY',
#    'time_sent': 1699107088184333,
#    'phase': 'S1903M',
#    'message': "I'm moving into Baltic Sea to do that this turn",
#    'truth': None,
#    'annotation': 'yes'}],
#  'F1903M': [{'sender': 'ENGLAND',
#    'recipient': 'FRANCE',
#    'time_sent': 1699107479615143,
#    'phase': 'F1903M',
#    'message': 'I might move NAO back to Norwegian sea.',
#    'truth': None,
#    'annotation': 'yes'}],
#  'S1904M': [{'sender': 'ITALY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699108612692856,
#    'phase': 'S1904M',
#    'message': "You ok with me sending Ven->Tyr? I'm trying to work with Turkey, but obviously I have to be able to defend myself, or I'm dead too",
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'ITALY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699108636435325,
#    'phase': 'S1904M',
#    'message': 'I think you and England just have to work together against Russia. You and England can even give France Holland, if necessary',
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'ITALY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699108828195860,
#    'phase': 'S1904M',
#    'message': 'If Turkey stabs me this turn, I have to do whatever I can to stop Russia from killing me. That means sending an army to Tyrolia',
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'TURKEY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699108878961674,
#    'phase': 'S1904M',
#    'message': "Keep defending against Russia. I'm trying to convince France to stop attacking you.",
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'ITALY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699109009695333,
#    'phase': 'S1904M',
#    'message': "Russia has 4 units bordering Tri, I have 2. I can't take Tri even with Turkey's help. I need to move to Tyr",
#    'truth': None,
#    'annotation': 'yes'}],
#  'S1905M': [{'sender': 'RUSSIA',
#    'recipient': 'GERMANY',
#    'time_sent': 1699109924738403,
#    'phase': 'S1905M',
#    'message': 'I need your help against Turkey',
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'RUSSIA',
#    'recipient': 'GERMANY',
#    'time_sent': 1699110005852769,
#    'phase': 'S1905M',
#    'message': 'But France is getting too strong',
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'RUSSIA',
#    'recipient': 'FRANCE',
#    'time_sent': 1699110210125879,
#    'phase': 'S1905M',
#    'message': "I can't help in England right now",
#    'truth': None,
#    'annotation': 'yes'}],
#  'F1905M': [{'sender': 'RUSSIA',
#    'recipient': 'FRANCE',
#    'time_sent': 1699110434950024,
#    'phase': 'F1905M',
#    'message': "Sorry, I didn't see this",
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'TURKEY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699110483026203,
#    'phase': 'F1905M',
#    'message': 'Why are you letting Russia take your centers?',
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'TURKEY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699110725594887,
#    'phase': 'F1905M',
#    'message': 'Russia is going to become too strong and go for you next.',
#    'truth': None,
#    'annotation': 'yes'}],
#  'F1906M': [{'sender': 'RUSSIA',
#    'recipient': 'GERMANY',
#    'time_sent': 1699112199538080,
#    'phase': 'F1906M',
#    'message': "Sorry, I'll attack Italy",
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'RUSSIA',
#    'recipient': 'FRANCE',
#    'time_sent': 1699112551101856,
#    'phase': 'F1906M',
#    'message': "I'm moving to Bohemia to attack Italy",
#    'truth': None,
#    'annotation': 'yes'},
#   {'sender': 'RUSSIA',
#    'recipient': 'FRANCE',
#    'time_sent': 1699112589273036,
#    'phase': 'F1906M',
#    'message': 'I want to work with you',
#    'truth': None,
#    'annotation': 'yes'}],
#  'F1907M': [{'sender': 'TURKEY',
#    'recipient': 'GERMANY',
#    'time_sent': 1699113524703964,
#    'phase': 'F1907M',
#    'message': "I'm worried that France is going to win this game.",
#    'truth': None,
#    'annotation': 'yes'}]}
